# %%
import rasterio
from rasterio.plot import show
from matplotlib import pyplot

# %%
src = rasterio.open('Red Sea depth.asc')
pyplot.imshow(src.read(1), cmap='pink')
pyplot.show()

# %%
show(src.read(), transform=src.transform)
# Out:
# <Axes: >
